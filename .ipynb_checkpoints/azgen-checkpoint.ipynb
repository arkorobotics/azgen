# %%
#import sys
#!{sys.executable} -m pip install utm

# %% [markdown]
# # 21 Working with Web Coverage Services
#
# The Web Coverage Service (WCS) is a standard issued by the Open Geospatial Consortium (OGC). It is designed to simplify remote access to coverages, commonly known as raster maps in GIS. WCS functions over the HTTP protocol, setting out how to obtain data and meta-data using the requests available in that protocol. In practice it allows raster maps to be obtained from a web browser or from any other programme that uses the protocol.
#
# Source: https://www.isric.org/web-coverage-services-wcs

# %% [markdown]
# ## Set File Paths and download Tutorial Data
#
# If you downloaded the latest `GemGIS` version from the Github repository, append the path so that the package can be imported successfully. Otherwise, it is recommended to install `GemGIS` via `pip install gemgis` and import `GemGIS` using `import gemgis as gg`. In addition, the file path to the folder where the data is being stored is set. The tutorial data is downloaded using Pooch (https://www.fatiando.org/pooch/latest/index.html) and stored in the specified folder. Use `pip install pooch` if Pooch is not installed on your system yet.

# %%
import gemgis as gg

file_path ='data/maps/'

# %% [markdown]
# ## Loading the WCS Service and loading WMS Data
#
# For this example, the digital elevation model of the State of Northrhine Westfalia will be downloaded. More information and the license for using the data can be found [here](https://www.bezreg-koeln.nrw.de/brk_internet/geobasis/hoehenmodelle/gelaendemodell/index.html).
#
# ### Loading the WCS Service
# The WCS Server is being accessed via OWSLib. The attributes `url` and `version` are needed for the following request.

# %%
wcs_url = 'https://www.wms.nrw.de/geobasis/wms_nw_dop'
wcs = gg.web.load_wcs(url=wcs_url)
print(type(wcs))
wcs
# Out:
# <class 'owslib.coverage.wcs201.WebCoverageService_2_0_1'>

# %%
wcs.url
# Out:
# 'https://www.wcs.nrw.de/geobasis/wcs_nw_dgm'

# %%
wcs.version
# Out:
# '2.0.1'

# %% [markdown]
# ### Load WMS Layer and Map
#
# A map of the Aachen area is loaded to later on plot the downloaded Digital Elevation Model data.

# %%
import utm

summit_lat = 34.0738
summit_long = -118.8328
summit_alt = 764

summit_lat_min = float('{:.8f}'.format(summit_lat-0.005))
summit_lat_max = float('{:.8f}'.format(summit_lat+0.005))
summit_long_min = float('{:.8f}'.format(summit_long-0.005))
summit_long_max = float('{:.8f}'.format(summit_long+0.005))


summit_extent = [summit_long_min,summit_long_max,summit_lat_min,summit_lat_max]

print(summit_extent)
# Out:
# [-118.8378, -118.8278, 34.0688, 34.0788]

# %%
wms = gg.web.load_wms('https://ows.terrestris.de/osm/service?')

# %%
wms_map = gg.web.load_as_array('https://ows.terrestris.de/osm/service?',
                             'nw_dop_rgb', 'default', 'EPSG:4326', summit_extent, [2000, 2000], 'image/png')
# Out:
# ---------------------------------------------------------------------------
# ServiceException                          Traceback (most recent call last)
# <ipython-input-111-70b5e71008c4> in <module>
# ----> 1 wms_map = gg.web.load_as_array('https://ows.terrestris.de/osm/service?',
#       2                              'nw_dop_rgb', 'default', 'EPSG:4326', summit_extent, [2000, 2000], 'image/png')
#
# ~/Library/Python/3.8/lib/python/site-packages/gemgis/web.py in load_as_array(url, layer, style, crs, bbox, size, filetype, transparent, save_image, path, overwrite_file, create_directory)
#     460
#     461     # Creating WMS map object
# --> 462     wms_map = load_as_map(url=url,
#     463                           layer=layer,
#     464                           style=style,
#
# ~/Library/Python/3.8/lib/python/site-packages/gemgis/web.py in load_as_map(url, layer, style, crs, bbox, size, filetype, transparent, save_image, path, overwrite_file, create_directory)
#     264
#     265     # Creating map object
# --> 266     wms_map = wms.getmap(layers=[layer], styles=[style], srs=crs, bbox=tuple([bbox[0], bbox[2], bbox[1], bbox[3]]),
#     267                          size=tuple(size), format=filetype,
#     268                          transparent=transparent)
#
# ~/Library/Python/3.8/lib/python/site-packages/owslib/map/wms111.py in getmap(self, layers, styles, srs, bbox, format, size, time, transparent, bgcolor, exceptions, method, timeout, **kwargs)
#     260         self.request = bind_url(base_url) + data
#     261
# --> 262         u = openURL(base_url, data, method, timeout=timeout or self.timeout, auth=self.auth, headers=self.headers)
#     263
#     264         # check for service exceptions, and return
#
# ~/Library/Python/3.8/lib/python/site-packages/owslib/util.py in openURL(url_base, data, method, cookies, username, password, timeout, headers, verify, cert, auth)
#     233             if serviceException is not None:
#     234                 # and we need to deal with some message nesting
# --> 235                 raise ServiceException('\n'.join([t.strip() for t in serviceException.itertext() if t.strip()]))
#     236
#     237     return ResponseWrapper(req)
#
# ServiceException: unknown layer: nw_dop_rgb

# %% [markdown]
# ### Plot WMS Data

# %%
import matplotlib.pyplot as plt 
import utm

plt.figure(figsize = (12,12))
plt.imshow(wms_map, extent = summit_extent)
plt.grid()
plt.ylabel('lat [deg]')
plt.xlabel('long [deg]')
#plt.text(summit_lat,summit_long, 'W6/SC-229', size = 14)
# Out:
# Text(0.5, 0, 'long [deg]')

# %% [markdown]
# ## Creating and Executing WCS Request
#
# The WCS needs to be created by providing min and max values for X and Y locations. Here, a for loop is created to automatically download four tiles with an extent of 2 by 2 km each. Due to their size, they will be saved outside the repository.

# %%
gg.web.load_as_files(wcs_url=wcs.url,
                     version=wcs.version,
                     identifier='nw_dgm',
                     form='image/tiff',
                     extent=summit_extent,
                     size=2000,
                     path=file_path,
                     create_directory=True)
# Out:
# Extent X:  0.010000000000005116  m
# Extent Y:  0.00999999999999801  m
# Number of tiles in X directions:  0
# Number of tiles in Y directions:  0
# Total Number of Tiles:  0
# 0it [00:00, ?it/s]

# %% [markdown]
# ## Create List of File paths
#
# A list of file paths is created for the subsequent merging of the data.

# %%
dem_fps = gg.raster.create_filepaths(dirpath=file_path, 
                                     search_criteria='tile*.tif')
dem_fps[:4]
# Out:
# ['/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5628000_5630000.tif',
#  '/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5626000_5628000.tif',
#  '/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5630000_5632000.tif',
#  '/Users/arko/GitHub/azgen/data/maps/tile_292000_294000_5628000_5630000.tif']

# %% [markdown]
# ## Create List of Tiles
#
# The above created list of file paths is automatically being created when executing the function below. In addition, a list of the loaded tiles is created.

# %%
src_files_to_mosaic = gg.raster.create_src_list(filepaths=dem_fps)
src_files_to_mosaic[:15]
# Out:
# [<open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5628000_5630000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5626000_5628000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_296000_298000_5630000_5632000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_292000_294000_5628000_5630000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_294000_296000_5628000_5630000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_292000_294000_5630000_5632000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_294000_296000_5626000_5628000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_292000_294000_5626000_5628000.tif' mode='r'>,
#  <open DatasetReader name='/Users/arko/GitHub/azgen/data/maps/tile_294000_296000_5630000_5632000.tif' mode='r'>]

# %% [markdown]
# ## Merge tiles to mosaic
#
# The single files can now automatically be merged to form a mosaic. In addition, the transform of the raster is being returned to save the raster later on.

# %%
mosaic, transform = gg.raster.merge_tiles(src_files=src_files_to_mosaic)

# %%
mosaic
# Out:
# array([[200.71, 200.72, 200.72, ..., 204.42, 204.43, 204.44],
#        [200.72, 200.74, 200.75, ..., 204.42, 204.44, 204.49],
#        [200.75, 200.74, 200.75, ..., 204.41, 204.46, 204.48],
#        ...,
#        [329.05, 328.88, 328.74, ..., 242.43, 242.42, 242.38],
#        [329.34, 329.08, 328.9 , ..., 242.45, 242.41, 242.32],
#        [329.45, 329.28, 329.05, ..., 242.45, 242.38, 242.34]],
#       dtype=float32)

# %%
transform
# Out:
# Affine(1.0, 0.0, 292000.0,
#        0.0, -1.0, 5632000.0)

# %% [markdown]
# ## Safe Raster to disc

# %%
import numpy as np
gg.raster.save_as_tiff(raster=np.flipud(mosaic), 
                       path=file_path +'raster.tif',
                       extent=summit_extent, 
                       crs='EPSG:4326', 
                       transform=transform,
                       overwrite_file=True)
# Out:
# Raster successfully saved

# %% [markdown]
# ## Plot DEM
#
# The mosaic/DEM can now be plotted using the built-in rasterio functionality or using matplotlib.

# %%
im = plt.imshow(mosaic, cmap='terrain', vmax=400, extent = summit_extent)
plt.colorbar(im)

# %%
plt.figure(figsize = (12,12))
plt.imshow(wms_map, extent= [290000, 300000,5625000,5633000])
plt.grid()
plt.ylabel('Y [m]')
plt.xlabel('X [m]')
plt.text(294500,5629750, 'Aachen', size = 14)
im = plt.imshow(mosaic, cmap='terrain', vmax=400, extent = [292000,298000,5626000,5632000])
plt.xlim(290000, 300000)
plt.ylim(5625000,5633000)
# Out:
# (5625000.0, 5633000.0)
